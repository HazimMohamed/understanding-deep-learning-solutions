# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap03/3_1_Shallow_Networks_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 3.1 -- Shallow neural networks I**
#
# The purpose of this notebook is to gain some familiarity with shallow neural networks with 1D inputs.  It works through an example similar to figure 3.3 and experiments with different activation functions. <br>
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and write code to complete the functions. There are also questions interspersed in the text.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Imports math library
import numpy as np
# Imports plotting library
import matplotlib.pyplot as plt

# %% [markdown]
# Let's first construct the shallow neural network with one input, three hidden units, and one output described in section 3.1 of the book.

# %%
# Define the Rectified Linear Unit (ReLU) function
def ReLU(preactivation):
  activation = np.clip(preactivation, 0, np.infty);
  return activation

# %%
# Make an array of inputs
z = np.arange(-5,5,0.1)
RelU_z = ReLU(z)

# Plot the ReLU function
fig, ax = plt.subplots()
ax.plot(z,RelU_z,'r-')
ax.set_xlim([-5,5]);ax.set_ylim([-5,5])
ax.set_xlabel('z'); ax.set_ylabel('ReLU[z]')
ax.set_aspect('equal')
plt.show()

# %%
# Define a shallow neural network with, one input, one output, and three hidden units
def shallow_1_1_3(x, activation_fn, phi_0,phi_1,phi_2,phi_3, theta_10, theta_11, theta_20, theta_21, theta_30, theta_31):
  # TODO Replace the code below to compute the three initial lines
  # from the theta parameters (i.e. implement equations at bottom of figure 3.3a-c).  These are the preactivations
  pre_1 = theta_10 + theta_11 * x
  pre_2 = theta_20 + theta_21 * x
  pre_3 = theta_30 + theta_31 * x

  # Pass these through the ReLU function to compute the activations as in
  # figure 3.3 d-f
  act_1 = activation_fn(pre_1)
  act_2 = activation_fn(pre_2)
  act_3 = activation_fn(pre_3)

  # TODO Replace the code below to weight the activations using phi1, phi2 and phi3
  # To create the equivalent of figure 3.3 g-i
  w_act_1 = phi_1 * act_1
  w_act_2 = phi_2 * act_2
  w_act_3 = phi_3 * act_3

  # TODO Replace the code below to combining the weighted activations and add
  # phi_0 to create the output as in figure 3.3 j
  y = w_act_1 + w_act_2 + w_act_3 + phi_0

  # Return everything we have calculated
  return y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3

# %%
# Plot the shallow neural network.  We'll assume input in is range [0,1] and output [-1,1]
# If the plot_all flag is set to true, then we'll plot all the intermediate stages as in Figure 3.3
def plot_neural(x, y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3, plot_all=False, x_data=None, y_data=None, print_params=False, x_lim=(0,1), y_lim=(-1,1)):

  # Plot intermediate plots if flag set
  if plot_all:
    fig, ax = plt.subplots(3,3)
    fig.set_size_inches(8.5, 8.5)
    fig.tight_layout(pad=3.0)
    ax[0,0].plot(x,pre_1,'r-'); ax[0,0].set_ylabel('Preactivation')
    ax[0,1].plot(x,pre_2,'b-'); ax[0,1].set_ylabel('Preactivation')
    ax[0,2].plot(x,pre_3,'g-'); ax[0,2].set_ylabel('Preactivation')
    ax[1,0].plot(x,act_1,'r-'); ax[1,0].set_ylabel('Activation')
    ax[1,1].plot(x,act_2,'b-'); ax[1,1].set_ylabel('Activation')
    ax[1,2].plot(x,act_3,'g-'); ax[1,2].set_ylabel('Activation')
    ax[2,0].plot(x,w_act_1,'r-'); ax[2,0].set_ylabel('Weighted Act')
    ax[2,1].plot(x,w_act_2,'b-'); ax[2,1].set_ylabel('Weighted Act')
    ax[2,2].plot(x,w_act_3,'g-'); ax[2,2].set_ylabel('Weighted Act')

    for plot_y in range(3):
      for plot_x in range(3):
        ax[plot_y,plot_x].set_xlim(x_lim);ax[plot_x,plot_y].set_ylim(y_lim)
        ax[plot_y,plot_x].set_aspect(0.5)
      ax[2,plot_y].set_xlabel('Input, $x$');
    plt.show()
      
  fig, ax = plt.subplots()
  ax.plot(x,y)
  ax.set_xlabel('Input, $x$'); ax.set_ylabel('Output, $y$')
  ax.set_xlim(x_lim);ax.set_ylim(y_lim)
  ax.set_aspect(0.5)
  if x_data is not None:
    ax.plot(x_data, y_data, 'mo')
    for i in range(len(x_data)):
      ax.plot(x_data[i], y_data[i],)
  plt.show()

# %%
# Now lets define some parameters and run the neural network
theta_10 =  0.3 ; theta_11 = -1.0
theta_20 = -1.0  ; theta_21 = 2.0
theta_30 = -0.5  ; theta_31 = 0.65
phi_0 = -0.3; phi_1 = 2.0; phi_2 = -1.0; phi_3 = 7.0

# Define a range of input values
x = np.arange(0,1,0.01)

# We run the neural network for each of these input values
y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3 = \
    shallow_1_1_3(x, ReLU, phi_0,phi_1,phi_2,phi_3, theta_10, theta_11, theta_20, theta_21, theta_30, theta_31)
# And then plot it
plot_neural(x, y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3, plot_all=True)

# %% [markdown]
# If your code is correct, then the final output should look like this:
# <img src="data:image/svg+xml;base64,...">

# %% [markdown]
# Now let's play with the parameters to make sure we understand how they work.  The original  parameters were:
#
# $\theta_{10} =  0.3$ ; $\theta_{11} = -1.0$<br>
# $\theta_{20} =  -1.0$ ; $\theta_{21} = 2.0$<br>
# $\theta_{30} =  -0.5$ ; $\theta_{31} = 0.65$<br>
# $\phi_0 = -0.3; \phi_1 = 2.0; \phi_2 = -1.0; \phi_3 = 7.0$

# %%
import pandas as pd
from IPython.display import display, Markdown

def print_params(phi_0, phi_1, phi_2, phi_3, theta_10, theta_20, theta_30, theta_11, theta_21, theta_31, title=None):    
    output_df = pd.DataFrame(
        {
            "Bias (theta_o0)":   [theta_10, theta_20, theta_30],
            "Weight (theta_o1}": [theta_11, theta_21, theta_31],
            "Scale (phi) ": [phi_1, phi_2, phi_3]
        },
        index=["n1", "n2", "n3"]
    )

    if title:
        display(Markdown(f'#### {title}'))
    display(output_df)        # In plain Python, replace with: print(output_df)
    print(f'φ0 (b_out): {phi_0}')        # Or: print(hidden_df)

print_params(-0.3, 2.0, -1.0, 7.0, 0.3, -1.0, -0.5, -1.0, 2.0, 0.65, title='Original weights')
# Out:
# #### Original weights
#     Bias (theta_o0)  Weight (theta_o1}  Scale (phi)
# n1              0.3              -1.00           2.0
# n2             -1.0               2.00          -1.0
# n3             -0.5               0.65           7.0
# φ0 (b_out): -0.3

# %% [markdown]
# ### 1. Predict what effect changing phi_0 will have on the network.
#
# $\phi_0$ changes moves the function up and down with respect to y.
#
# ### 2. Predict what effect multiplying phi_1, phi_2, phi_3 by 0.5 would have.  Check if you are correct
#
# It would squeeze the predicted function vertically.
#
# ### 3. Predict what effect multiplying phi_1 by -1 will have.  Check if you are correct.
#
# It will lead the first segment to go in an upward direction instead of a downward one.
#
# ### 4. Predict what effect setting theta_20 to -1.2 will have.  Check if you are correct.
#
# It will delay the start of the third segment because the ReLU activates a little bit later.
#
# ### 5. Change the parameters so that there are only two "joints" (including outside the range of the plot) There are actually three ways to do this. See if you can figure them all out
#
# I. You can functionally eliminate neurons by setting their weight ($\theta_{\bullet 1}$) to 0 and their bias ($\theta_{\bullet 0}$) to negative. So we can mute the last neuron and then only have two joints.
#
# II. You can functionally eliminate a neuron by setting its $\phi$ value to 0.
#
# III. If we align the joints of two of the neurons, then we can reduce the number of joints in the function. We can trivially do this by making their $\theta$ parameters the same.
#
# ### 6. With the original parameters, the second line segment is flat (i.e. has slope zero) How could you change theta_10 so that all of the segments have non-zero slopes?
#
# If we make $\theta_{10}$ a value such that the x-intercept of the function is greater than the minimum x-intercept of the remaining functions there should be no flat segments. We can easily do this by just increasing theta_10 until it happens.
#
# ### 7. What do you predict would happen if you multiply theta_20 and theta21 by 0.5, and phi_2 by 2.0? Check if you are correct.
#
# I think it would NOT cancel out since $\phi_2 \cdot ReLU(\theta_{20} + \theta_{21} x) \neq 2 \phi_2 \cdot ReLU(0.5 \theta_{20} + 0.5 \theta_{21} x)$. As far as what WOULD happen. I don't know.
#
# <hr>
#
# I was wrong apparently. The equation $\phi_2 \cdot ReLU(\theta_{20} + \theta_{21} x) = \alpha^{-1} \phi_2 \cdot ReLU(\alpha (\theta_{20} + \theta_{21} x))$ holds as long as $\alpha > 0$. I can prove this to myself as follows:
#
# If $\alpha > 0$ then the positive part of the ReLU will scale by $\alpha$ the negative side will just get coerced to 0 as part of ReLU. But only if $\alpha > 0$. If we have $\alpha < 0$ then it will essentially reverse the ReLU and scale it. The parts invisible before would be visible in the output and vise versa.
# $
#
#
# ### 8. What do you predict would happen if you multiply theta_20 and theta21 by -0.5, and phi_2 by -2.0? Checkyou are correct.if y
#
# Based on the above I would predict that this would invert the ReLU output by flipping across it's original jst.ou are correct.

# %%
# If you don't believe any of the above test it yourself!

theta_10 =  0.3 ; theta_11 = -1.0
theta_20 = -1  ; theta_21 = 2
theta_30 = -0.5  ; theta_31 = 0.65
phi_0 = -0.3; phi_1 = 2.0; phi_2 = -1.0; phi_3 = 7.0

# Define a range of input values
x = np.arange(0,1,0.01)

# We run the neural network for each of these input values
y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3 = \
    shallow_1_1_3(x, ReLU, phi_0,phi_1,phi_2,phi_3, theta_10, theta_11, theta_20, theta_21, theta_30, theta_31)
# And then plot it
plot_neural(x, y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3, plot_all=True)

# %% [markdown]
# # Least squares loss
#
# Now let's consider fitting the network to data.  First we need to define the loss function.  We'll use the least squares loss:
#
# \begin{equation}
# L[\boldsymbol\phi] = \sum_{i=1}^{I}(y_{i}-\text{f}[x_{i},\boldsymbol\phi])^2
# \end{equation}
#
# where $(x_i,y_i)$ is an input/output training pair and $\text{f}[\bullet,\boldsymbol\phi]$ is the neural network with parameters $\boldsymbol\phi$.  The first term in the brackets is the ground truth output and the second term is the prediction of the model

# %%
# Least squares function
def least_squares_loss(y_train, y_predict):
  loss = np.sum((y_train - y_predict)**2)

  return loss

# %%
# Now lets define some parameters, run the neural network, and compute the loss
theta_10 =  0.3 ; theta_11 = -1.0
theta_20 = -1.2  ; theta_21 = 2.0
theta_30 = -0.5  ; theta_31 = 0.65
phi_0 = 0.3; phi_1 = -2.0; phi_2 = -1.0; phi_3 = 7.0

# Define a range of input values
x = np.arange(0,1,0.01)

x_train = np.array([0.09291784,0.46809093,0.93089486,0.67612654,0.73441752,0.86847339,\
                   0.49873225,0.51083168,0.18343972,0.99380898,0.27840809,0.38028817,\
                   0.12055708,0.56715537,0.92005746,0.77072270,0.85278176,0.05315950,\
                   0.87168699,0.58858043])
y_train = np.array([-0.15934537,0.18195445,0.451270150,0.13921448,0.09366691,0.30567674,\
                    0.372291170,0.40716968,-0.08131792,0.41187806,0.36943738,0.3994327,\
                    0.019062570,0.35820410,0.452564960,-0.0183121,0.02957665,-0.24354444, \
                    0.148038840,0.26824970])

# We run the neural network for each of these input values
y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3 = \
    shallow_1_1_3(x, ReLU, phi_0,phi_1,phi_2,phi_3, theta_10, theta_11, theta_20, theta_21, theta_30, theta_31)
# And then plot it
plot_neural(x, y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3, plot_all=True, x_data = x_train, y_data = y_train)

# Run the neural network on the training data
y_predict, *_ = shallow_1_1_3(x_train, ReLU, phi_0,phi_1,phi_2,phi_3, theta_10, theta_11, theta_20, theta_21, theta_30, theta_31)

# Compute the least squares loss and print it out
loss = least_squares_loss(y_train,y_predict)
print('Your Loss = %3.3f, My loss = 0.181'%(loss))

# Manipulate the parameters (by hand!) to make the function
# fit the data better and try to reduce the loss to as small a number
# as possible.  The best that I could do was 
# Tip... start by manipulating phi_0.
# It's not that easy, so don't spend too much time on this!
# Out:
# Your Loss = 0.162, My loss = 0.181

# %% [markdown]
# ##### Yay I got a tighter fit than the professor! Only took me **5 hours**

# %% [markdown]
# ### Problems 3.1 - 3.8
#
# #### Problem 3.1
# **What kind of mapping from input to output would be created if the activation function in equation 3.1 was linear so that a[z] = ψ0 + ψ1z? What kind of mapping would be created if the activation function was removed, so a[z] = z?**
#
# If the activation function was linear, then we would have a sum of linear functions, which itself would be linear. This would make neural networks into a suboptimal form of linear regression. Similarly, if the activation function were the identity function, then our model would also produce exclusively linear mappings.
#
# #### Problem 3.2
# **For each of the four linear regions in figure 3.3j, indicate which hidden units are inactive and which are active (i.e., which do and do not clip their inputs).**
#
# 1st linear region: only (i) is active
# 2nd linear region: (g) and (i) are active
# 3rd linear region: All three (g), (h), and (i) are active
# 4th linear region: (h) and (g) are active
#
# ### Problem 3.3
# **Derive expressions for the positions of the “joints” in function in figure 3.3j in terms of the ten parameters ϕ and the input x. Derive expressions for the slopes of the four linear regions.**
#
# Oooo. This is a fun one! The position of a joint is uniquely determined by its x-value, since we can feed an x-value into the network and obtain the Y value. In plain terms, the joints occur at places where the original functions had an x-intercept. Since $ \theta_{10} + \theta_{11} x = 0 \implies x = \tfrac{-\theta_{10}}{\theta_{11}} $ can describe the x-position of the joints as:
#
# $$
# \left\{ \dfrac{-\theta_{k0}}{\theta_{k1}} \; \middle| \; k \in \{1,2,3\} \right\}
# $$
#
# For the example above with values:
#
# $$
# \theta_{10} =  0.3 \;\; \theta_{11} = -1.0 \\
# \theta_{20} = -1  \;\; \theta_{21} = 2 \\
# \theta_{30} = -0.5  \;\; \theta_{31} = 0.65 \\
# $$
#
#
# We get joints:
#
# $$
# \left\{ 0.3, 0.5, ~0.77 \right\}
# $$
#
# Which vaguely matches the graph. For slope we can just run the model and find the slope for a given segment given its start and end points.
#
# $$
# m = \dfrac{Sn(x_0, \phi)}{Sn(x_1, \phi)}
# $$
#
# $\phi$ is the set of all parameters and $Sn$ is the model and $r_{start} \le x_0 < x_1 \le r_{end}$
#
#
# ### Problem 3.4
#
# **Draw a version of figure 3.3 where the y-intercept and slope of the third hidden
# unit have changed as in figure 3.14c. Assume that the remaining parameters remain the same**
#
#
# ![image.png](attachment:25107ed3-cdb1-4b5f-89bb-2b75615dbc83.png
#
# ### Problem 3.5
#
# **Prove that the follwing property holds for $\alpha \in \mathbb{R}^+$:**
#
#
# $$
# \operatorname{ReLU}[a \cdot z] = \alpha \cdot \operatorname{ReLU}[z]
# $$
#
# Well, considering:
#
# $$
# \operatorname{ReLU}[x] = \begin{cases}
# x & x > 0 \\
# 0 & x < 0
# \end{cases}
# $$
#
# We can reason that the boundary between the rectified and non-rectified parts of the function will not change if $\alpha > 0$. We notice that the negative side times a positive alpha will still rectify to 0. Then we can note $\operatorname{ReLU}[x]=x \implies \alpha \cdot \operatorname{ReLU}[x] = \alpha \cdot x = \operatorname{ReLU}[\alpha \cdot x]$ for the non-rectified side.?
# )

# %% [markdown]
# ### Problem 3.6
#
# **Following on from problem 3.5, what happens to the shallow network defined in
# equations 3.3 and 3.4 when we multiply the parameters $\theta_{10}$  and $\theta_{11}$1 by a positive constant $\alpha$ and divide the slope $\phi_1$ by the same parameter $\alpha$? What happens if $\alpha$ is negative**?
#
# Well based on 3.5 we know that $\operatorname{ReLU}[\alpha\cdot z] = \alpha \cdot \operatorname{ReLU}[z]$ for $\alpha > 0$. Since the only term to change in the output (those than interact with $\theta_{10}$ and $\theta_{11}$) would be $\alpha^{-1} \phi_{1} \operatorname{ReLU}[\alpha \cdot (\theta_{10} + \theta_{11} x)] = \phi_{1} \alpha \cdot \alpha^{-1} \operatorname{ReLU}[\theta_{10} + \theta_{11} x] = \phi_{1} \operatorname{ReLU}[\theta_{10} + \theta_{11} x]$ then we conclude for $\alpha > 0$ that this does nothing. However the same property would not hold for a negative scalar.

# %% [markdown]
# ### Problem 3.7
#
# **Consider fitting the model in equation 3.1 using a least squares loss function. Does this loss function have a unique minimum? i.e., is there a single “best” set of parameters?**
#
# **3.1: $y_i = \phi_0 + \phi_1 \operatorname{ReLU}[\theta_{10} + \theta_{11} x] + \phi_2 \operatorname{ReLU}[\theta_{20} + \theta_{21} x] + \phi_3 \operatorname{ReLU}[\theta_{30} + \theta_{31} x]$$*
#
# We can prove that there is more than one solution for the parameters by contradiction. Assume there is a unqiue set of parameters that produces a minimum loss $k$. If we produce a new set of parameters by applying the operation in **3.6** with any arbitrary positive $\alpha$, we produce a new set of parameters that also produce the same output as the initial set. Therefore, we violate our initial assumption that this is a unique set of parameters to produce loss $k$.*

# %% [markdown]
# ### Problem 3.8
#
# **Consider replacing the ReLU activation function with (i) the Heaviside step function heaviside[z], (ii) the hyperbolic tangent function tanh[z], and (iii) the rectangular function rect[z], where:**
#
# $$
# \operatorname{heaviside}[x] = \begin{cases}
# 0 & x < 0 \\
# 1 & x \ge 0
# \end{cases}
# $$
#
# $$
# \operatorname{rect}[x] = \begin{cases}
# 0 & x < 0 \\
# 1 & 0 \leq x \leq 1 \\
# 0 & x > 1
# \end{cases}
# $$
#
# Redraw a version of figure 3.3 for each of these functions. The original parameters were:  $ \phi = \{ \phi_0, \phi_1, \phi_2, \phi_3, \theta_{10}, \theta_{11}, \theta_{20}, \theta_{21}, \theta_{30}, \theta_{31} \} = \{−0.23, −1.3, 1.3, 0.66, −0.2, 0.4, −0.9, 0.9, 1.1, −0.7 \} $. Provide an informal description of the family of functions that can be created by neural networks with one input, three hidden units, and one output for each activation function.

# %%
# Now lets define some parameters and run the neural network
theta_10 =  -0.2 ; theta_11 = -0.4
theta_20 = -0.9  ; theta_21 = 0.9
theta_30 = 1.1  ; theta_31 = -0.7
phi_0 = -0.23; phi_1 = -1.3; phi_2 = 1.3; phi_3 = 0.66

# Define a range of input values
x = np.arange(-3,3,0.01)
x_lim = (-3,3)
y_lim = (-5,5)

def heaviside(x):
    return np.where(x < 0, 0, 1)

def rect(x):
    return np.where((x < 0) | (x > 1), 0, 1)

print("ReLU:")
# We run the neural network for each of these input values
y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3 = \
    shallow_1_1_3(x, ReLU, phi_0,phi_1,phi_2,phi_3, theta_10, theta_11, theta_20, theta_21, theta_30, theta_31)
# And then plot it
plot_neural(x, y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3, plot_all=True, x_lim=x_lim, y_lim=y_lim)

print("Heaviside:")
# We run the neural network for each of these input values
y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3 = \
    shallow_1_1_3(x, heaviside, phi_0,phi_1,phi_2,phi_3, theta_10, theta_11, theta_20, theta_21, theta_30, theta_31)
# And then plot it
plot_neural(x, y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3, plot_all=True, x_lim=x_lim, y_lim=y_lim)

print("Rect:")
# We run the neural network for each of these input values
y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3 = \
    shallow_1_1_3(x, rect, phi_0,phi_1,phi_2,phi_3, theta_10, theta_11, theta_20, theta_21, theta_30, theta_31)
# And then plot it
plot_neural(x, y, pre_1, pre_2, pre_3, act_1, act_2, act_3, w_act_1, w_act_2, w_act_3, plot_all=True, x_lim=x_lim, y_lim=y_lim)
# Out:
# ReLU:
# Heaviside:
# Rect:

# %% [markdown]
# They're a set of functions non-linear functions that have linear segments joined by at most 3*$b$ joints where $b$ is the maximum number of joints produced by the activation function on a linear input.
